# %%
import matplotlib.pylab as plt

import scipy

import numpy as np

import pandas as pd

from scipy.ndimage import gaussian_filter1d
def smooth(x, sigma = 1.5):
        return gaussian_filter1d(x, sigma)

# %% [markdown]
# ### new data

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-3.5h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.5):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_peaks_motifs_%s_newdata.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    #print(score_ave.iloc[:])
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
    #ax.set_ylim(0.95,1.35)
axs[3].legend( bbox_to_anchor=(1.57, 0.57),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)

plt.suptitle('Observed, ctcf & motifs, Rini\'s new data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_for_ctcf&motifs_Rini_new_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### old data

# %%
def smooth(x, sigma = 1.5):
        return gaussian_filter1d(x, sigma)


fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-6h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_peaks_motifs_%s_old_data.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.57),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed, ctcf & motifs, Rini\'s old data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_for_ctcf&motifs_Rini_old_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:41: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### new data, observed over expected

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-3.5h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.5):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_peaks_motifs_%s_newdata_observed_over_expected.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all directions', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.571, 0.57),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed over expected, ctcf & motifs, Rini\'s new data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_over_expected_for_ctcf&motifs_Rini_new_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### old data, observed over expected

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-6h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.5):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_peaks_motifs_%s_old_data_observed_over_expected.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.57),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed over expected, ctcf & motifs, Rini\'s old data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_over_expected_for_ctcf&motifs_Rini_old_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### new data, quartile

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-3.5h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.315):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_top_quartile_peaks_motifs_%s_newdata.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.587),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed, ctcf & motifs, top quartile, Rini\'s new data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_for_ctcf&motifs_top_quartile_Rini_new_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### old data, observed, quartile

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-6h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.15):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_top_quartile_peaks_motifs_%s_old_data.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.587),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed, ctcf & motifs, top quartile, Rini\'s old data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_for_ctcf&motifs_top_quartile_Rini_old_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-3.5h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.315):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_top_quartile_peaks_motifs_%s_newdata_observed_over_expected.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.587),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed over expected, ctcf & motifs, top quartile, Rini\'s new data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_over_expected_for_ctcf&motifs_top_quartile_Rini_new_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %%
fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-0h','Nipbl-6h','RAD21-0h', 'RAD21-6h', 'Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-0h','Pds5AB-6h']

def smooth(x, sigma = 1.315):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_recent/dots_vs_distance_top_quartile_peaks_motifs_%s_old_data_observed_over_expected.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
axs[1].set_title('convergent', fontsize = 11.5)
axs[2].set_title('divergent', fontsize = 11.5)
axs[3].set_title('tandem', fontsize = 11.5)
axs[0].set_title('all orientations', fontsize = 11.5)
for ax in axs:
    ax.grid(True)
    ax.set_xlabel('Distance [log10]', fontsize = 11.5)
axs[3].legend( bbox_to_anchor=(1.57, 0.587),loc='right')
axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
#plt.legend()
plt.suptitle('Observed over expected, ctcf & motifs, top quartile, Rini\'s old data', fontsize=15, y=1.05)
plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
plt.savefig('observed_over_expected_for_ctcf&motifs_top_quartile_Rini_old_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
# Out:
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
# /home1/rahmanin/.conda/envs/openmm-env/lib/python3.7/site-packages/ipykernel_launcher.py:39: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "ppt" which is no longer supported as of 3.3 and will become an error in 3.6

# %% [markdown]
# ### new data, orienational analysis

# %%
#fig, axs = plt.subplots(1, 4, figsize=(19, 3))  # 3 rows, 1 column

new_sample_dict=['WT','Nipbl-6h','Wapl-6h', 'Pds5AB+Nipbl-6h', 'Wapl+Nipbl-6h', 'Pds5AB-6h']

def smooth(x, sigma = 1.15):
        return gaussian_filter1d(x, sigma)
for name in new_sample_dict[:10]:
    #print(name)
    data=pd.read_csv('data_new/dots_vs_distance_peaks_motifs_%s_newdata.csv'%name)
    dist_conv=data[data['orientation']=='+-']['dist']
    score_conv=data[data['orientation']=='+-']['peak_score']
    dist_dive=data[data['orientation']=='-+']['dist']
    score_dive=data[data['orientation']=='-+']['peak_score']
    dist_tandemp=data[data['orientation']=='++']['dist']
    score_tandemp=data[data['orientation']=='++']['peak_score']
    dist_tandemn=data[data['orientation']=='--']['dist']
    score_tandemn=data[data['orientation']=='--']['peak_score']
    score_ave=data.groupby('dist')['peak_score'].mean()
    #axs[1].plot(np.log10(dist_conv),smooth(score_conv),label='%s'%name)
    #axs[0].plot(np.log10(dist_conv),smooth(score_ave),label='%s'%name)
    #axs[2].plot(np.log10(dist_conv),smooth(score_dive),label='%s'%name)
    #axs[3].plot(np.log10(dist_conv), smooth(score_tandemp), label='%s'%name)
    #print(len(score_conv),len(score_dive))
    #print(score_conv,score_dive)
    plt.plot(np.log10(dist_conv),smooth(score_conv.reset_index(drop=True)/score_dive.reset_index(drop=True)),label = '%s'%name)
#plt.ylabel('Peak score',fontsize = 11.5)
#plt.xlabel('off-diagonal distance [mb]',fontsize = 11.5)
plt.title(r'$\dfrac{convergent}{divergent}$, observed', fontsize = 11.5)
#axs[2].set_title('divergent', fontsize = 11.5)
#axs[3].set_title('tandem', fontsize = 11.5)
#axs[0].set_title('all orientations', fontsize = 11.5)
plt.xlabel('Distance [log10]', fontsize = 11.5)
#axs[3].legend( bbox_to_anchor=(1.57, 0.57),loc='right')
#axs[0].set_ylabel('peak score',fontsize = 11.5)
#plt.semilogx()
#plt.xlim(-20,5)
plt.legend()
#plt.suptitle('Observed, ctcf & motifs, Rini\'s new data', fontsize=15, y=1.05)
#plt.tight_layout(rect=[10, 10.3, 10.15, 10.95])
#plt.savefig('observed_for_ctcf&motifs_Rini_new_data.png',ppt=500, bbox_inches = 'tight')
plt.show()
